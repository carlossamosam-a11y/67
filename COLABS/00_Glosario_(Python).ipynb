# %% [markdown]
# <a href="https://colab.research.google.com/github/carlossamosam-a11y/67/blob/main/COLABS/00_Glosario_(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Glosario**
#
# 1. Divison entera (` // `)
# > *La Division entera es una division entre numeros en donde el resultado es siempre entero por tanto se redondea al entero menor*
# -----
# 2. Expresiones
# > Es una colección de operadores
# -----
# 3. Valor
# > Resultado de una expresión
# -----
# 4. Error: SyntaxError
# > Ocurre cuando llamo una función y tengo un error en su escritura (por ejemplo: abs 42, es un error pues no puse los parentesis en el 42)
# -----
# 5. Función `len()`
# >  Cuenta la cantidad de caracteres que tiene un string. Si no pongo los parentesis tengo un error de sintaxis
# -----
# 6. Error de tipo (TypeError)
# > Ocurre cuando se ejecuta una operación que no esta asociada a un tipo (Ejemplo: Dividir un string pues con string solo puedo * y /)
# -----
# 7. Debugging
# > Buscamos errores a partir de lo escrito en python
